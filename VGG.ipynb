# %%
# ================= Colab 單格腳本：VGG16 單字元 CAPTCHA 訓練 =================
# 0. 安裝必要套件（torch 與 torchvision 已預裝於 GPU 筆記本可省略再安裝）
# !pip -q install torch torchvision pillow matplotlib scikit-learn tqdm
# !unzip -o fonts.zip
# 1. 產生資料集 ----------------------------------------------------------------
#    假設你已經把 data.py、perturber.py、fonts/ 目錄上傳到 /content/
from data import generate_dataset, get_font_paths
import string, torch, numpy as np, matplotlib.pyplot as plt
from torchvision import transforms, models
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader
import torch.nn as nn
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from pathlib import Path
from tqdm import tqdm

# (1) 資料集參數
dataset_root = "dataset"
if not Path(dataset_root, "clean").exists():           # 若尚未產生則自動產生
    cfg = {
        "length": 1,
        "charset": string.digits + string.ascii_lowercase,
        "font_paths": get_font_paths("fonts"),         # 需有 fonts/
        "font_size": 42,
        "image_size": (60, 60),
        "bg_color": "white",
        "char_color": "black",
        "char_spacing": 4,
        "seed": 42,
        "x_jitter": 5,
        "y_jitter": 5,
        "wave_amplitude": 2.0,
        "background_blur": True,
    }
    generate_dataset(dataset_root, n_samples=5000, dataset_config=cfg, noise_config=None)

# 2. 資料載入與前處理 ------------------------------------------------------------
BATCH_SIZE   = 32
EPOCHS       = 10
LR           = 1e-3
SEED         = 42
DATASET_DIR  = f"{dataset_root}/clean"
torch.manual_seed(SEED)
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.Grayscale(num_output_channels=3),
    transforms.ToTensor(),
    transforms.Normalize([0.5]*3, [0.5]*3),
])
dataset = ImageFolder(root=DATASET_DIR, transform=transform)
num_classes = len(dataset.classes)
assert num_classes == 36, f"class 數應為 36, 目前 {num_classes}"
idx = np.arange(len(dataset)); np.random.seed(SEED); np.random.shuffle(idx)
split  = int(0.8*len(dataset))
train_set = torch.utils.data.Subset(dataset, idx[:split])
test_set  = torch.utils.data.Subset(dataset, idx[split:])
train_loader = DataLoader(train_set, batch_size=BATCH_SIZE, shuffle=True)
test_loader  = DataLoader(test_set,  batch_size=BATCH_SIZE, shuffle=False)
print(f"#train={len(train_set)}  #test={len(test_set)}")

# 3. 建立模型 -------------------------------------------------------------------
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device:", device)
model = models.vgg16(pretrained=True)
for p in model.features.parameters():
    p.requires_grad = False                         # 凍結卷積層
model.classifier[6] = nn.Linear(4096, num_classes)  # 36 類
model.to(device)
optimizer = torch.optim.Adam(model.classifier.parameters(), lr=LR)
criterion = nn.CrossEntropyLoss()

# 4. 訓練迴圈 -------------------------------------------------------------------
train_acc, test_acc, train_loss, test_loss = [], [], [], []
best_acc, best_wts = 0, None
for epoch in range(1, EPOCHS+1):
    # --- Train ---
    model.train(); t_corr=t_total=0; t_loss=0.0
    for x, y in tqdm(train_loader, desc=f"Epoch {epoch}/{EPOCHS} [train]", leave=False):
        x, y = x.to(device), y.to(device)
        optimizer.zero_grad()
        out = model(x)
        loss = criterion(out, y)
        loss.backward(); optimizer.step()
        t_loss += loss.item()*y.size(0)
        t_corr += (out.argmax(1)==y).sum().item()
        t_total += y.size(0)
    train_acc.append(t_corr/t_total); train_loss.append(t_loss/t_total)

    # --- Test ---
    model.eval(); v_corr=v_total=0; v_loss=0.0
    with torch.no_grad():
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            out = model(x)
            v_loss += criterion(out, y).item()*y.size(0)
            v_corr += (out.argmax(1)==y).sum().item()
            v_total += y.size(0)
    test_acc.append(v_corr/v_total); test_loss.append(v_loss/v_total)
    print(f"Epoch {epoch:02d} | TrainAcc={train_acc[-1]:.4f}  TestAcc={test_acc[-1]:.4f}")

    if test_acc[-1] > best_acc: best_acc, best_wts = test_acc[-1], model.state_dict()

# 5. 保存模型 --------------------------------------------------------------------
torch.save(best_wts, "vgg16_char_best.pt")
print(f"✅ Best test acc = {best_acc:.4f}  (weights saved)")

# 6. 繪圖 ------------------------------------------------------------------------
plt.figure(figsize=(12,5))
plt.subplot(1,2,1); plt.plot(train_acc,label='Train'); plt.plot(test_acc,label='Test')
plt.title("Accuracy"); plt.legend()
plt.subplot(1,2,2); plt.plot(train_loss,label='Train'); plt.plot(test_loss,label='Test')
plt.title("Loss"); plt.legend(); plt.show()

# 7. 混淆矩陣 --------------------------------------------------------------------
model.load_state_dict(best_wts); model.eval()
all_p, all_y = [], []
with torch.no_grad():
    for x,y in test_loader:
        out = model(x.to(device)); all_p += out.argmax(1).cpu().tolist(); all_y += y.tolist()
cm  = confusion_matrix(all_y, all_p)
fig, ax = plt.subplots(figsize=(10,10))
ConfusionMatrixDisplay(cm, display_labels=dataset.classes).plot(ax=ax, cmap='Blues',
                                                                xticks_rotation='vertical',
                                                                values_format='d')
plt.title("Confusion Matrix"); plt.show()
# ================================================================================
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 121.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 90.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 53.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 8.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 65.3 MB/s eta 0:00:00
# Archive:  fonts.zip
#    creating: fonts/
#   inflating: fonts/AGENCYB.TTF
#   inflating: fonts/AGENCYR.TTF
#   inflating: fonts/ALGER.TTF
#   inflating: fonts/ANTQUAB.TTF
#   inflating: fonts/ANTQUABI.TTF
#   inflating: fonts/ANTQUAI.TTF
#   inflating: fonts/arial.ttf
#   inflating: fonts/arialbd.ttf
#   inflating: fonts/arialbi.ttf
#   inflating: fonts/ariali.ttf
#   inflating: fonts/ARIALN.TTF
#   inflating: fonts/ARIALNB.TTF
#   inflating: fonts/ARIALNBI.TTF
#   inflating: fonts/ARIALNI.TTF
#   inflating: fonts/ariblk.ttf
#   inflating: fonts/ARLRDBD.TTF
#   inflating: fonts/bahnschrift.ttf
#   inflating: fonts/BASKVILL.TTF
#   inflating: fonts/BAUHS93.TTF
#   inflating: fonts/BELL.TTF
#   inflating: fonts/BELLB.TTF
#   inflating: fonts/BELLI.TTF
#   inflating: fonts/BERNHC.TTF
#   inflating: fonts/BKANT.TTF
#   inflating: fonts/BOD_B.TTF
#   inflating: fonts/BOD_BI.TTF
#   inflating: fonts/BOD_BLAI.TTF
#   inflating: fonts/BOD_BLAR.TTF
#   inflating: fonts/BOD_CB.TTF
#   inflating: fonts/BOD_CBI.TTF
#   inflating: fonts/BOD_CI.TTF
#   inflating: fonts/BOD_CR.TTF
#   inflating: fonts/BOD_I.TTF
#   inflating: fonts/BOD_PSTC.TTF
#   inflating: fonts/BOD_R.TTF
#   inflating: fonts/BOOKOS.TTF
#   inflating: fonts/BOOKOSB.TTF
#   inflating: fonts/BOOKOSBI.TTF
#   inflating: fonts/BOOKOSI.TTF
#   inflating: fonts/BRADHITC.TTF
#   inflating: fonts/BRITANIC.TTF
#   inflating: fonts/BRLNSB.TTF
#   inflating: fonts/BRLNSDB.TTF
#   inflating: fonts/BRLNSR.TTF
#   inflating: fonts/BROADW.TTF
#   inflating: fonts/BRUSHSCI.TTF
#   inflating: fonts/BSSYM7.TTF
#   inflating: fonts/calibri.ttf
#   inflating: fonts/calibrib.ttf
#   inflating: fonts/calibrii.ttf
#   inflating: fonts/calibril.ttf
#   inflating: fonts/calibrili.ttf
#   inflating: fonts/calibriz.ttf
#   inflating: fonts/CALIFB.TTF
#   inflating: fonts/CALIFI.TTF
#   inflating: fonts/CALIFR.TTF
#   inflating: fonts/CALIST.TTF
#   inflating: fonts/CALISTB.TTF
#   inflating: fonts/CALISTBI.TTF
#   inflating: fonts/CALISTI.TTF
#   inflating: fonts/cambriab.ttf
#   inflating: fonts/cambriai.ttf
#   inflating: fonts/cambriaz.ttf
#   inflating: fonts/Candara.ttf
#   inflating: fonts/Candarab.ttf
#   inflating: fonts/Candarai.ttf
#   inflating: fonts/Candaral.ttf
#   inflating: fonts/Candarali.ttf
#   inflating: fonts/Candaraz.ttf
#   inflating: fonts/CASTELAR.TTF
#   inflating: fonts/CENSCBK.TTF
#   inflating: fonts/CENTAUR.TTF
#   inflating: fonts/CENTURY.TTF
#   inflating: fonts/CHILLER.TTF
#   inflating: fonts/COLONNA.TTF
#   inflating: fonts/comic.ttf
#   inflating: fonts/comicbd.ttf
#   inflating: fonts/comici.ttf
#   inflating: fonts/comicz.ttf
#   inflating: fonts/consola.ttf
#   inflating: fonts/consolab.ttf
#   inflating: fonts/consolai.ttf
#   inflating: fonts/consolaz.ttf
#   inflating: fonts/constan.ttf
#   inflating: fonts/constanb.ttf
#   inflating: fonts/constani.ttf
#   inflating: fonts/constanz.ttf
#   inflating: fonts/COOPBL.TTF
#   inflating: fonts/COPRGTB.TTF
#   inflating: fonts/COPRGTL.TTF
#   inflating: fonts/corbel.ttf
#   inflating: fonts/corbelb.ttf
#   inflating: fonts/corbeli.ttf
#   inflating: fonts/corbell.ttf
#   inflating: fonts/corbelli.ttf
#   inflating: fonts/corbelz.ttf
#   inflating: fonts/cour.ttf
#   inflating: fonts/courbd.ttf
#   inflating: fonts/courbi.ttf
#   inflating: fonts/couri.ttf
#   inflating: fonts/CURLZ___.TTF
#   inflating: fonts/Deng.ttf
#   inflating: fonts/Dengb.ttf
#   inflating: fonts/Dengl.ttf
#   inflating: fonts/DUBAI-BOLD.TTF
#   inflating: fonts/DUBAI-LIGHT.TTF
#   inflating: fonts/DUBAI-MEDIUM.TTF
#   inflating: fonts/DUBAI-REGULAR.TTF
#   inflating: fonts/ebrima.ttf
#   inflating: fonts/ebrimabd.ttf
#   inflating: fonts/ELEPHNT.TTF
#   inflating: fonts/ELEPHNTI.TTF
#   inflating: fonts/ENGR.TTF
#   inflating: fonts/ERASBD.TTF
#   inflating: fonts/ERASDEMI.TTF
#   inflating: fonts/ERASLGHT.TTF
#   inflating: fonts/ERASMD.TTF
#   inflating: fonts/FELIXTI.TTF
#   inflating: fonts/FORTE.TTF
#   inflating: fonts/FRABK.TTF
#   inflating: fonts/FRABKIT.TTF
#   inflating: fonts/FRADM.TTF
#   inflating: fonts/FRADMCN.TTF
#   inflating: fonts/FRADMIT.TTF
#   inflating: fonts/FRAHV.TTF
#   inflating: fonts/FRAHVIT.TTF
#   inflating: fonts/framd.ttf
#   inflating: fonts/FRAMDCN.TTF
#   inflating: fonts/framdit.ttf
#   inflating: fonts/FREESCPT.TTF
#   inflating: fonts/FRSCRIPT.TTF
#   inflating: fonts/FTLTLT.TTF
#   inflating: fonts/FZSTK.TTF
#   inflating: fonts/FZYTK.TTF
#   inflating: fonts/Gabriola.ttf
#   inflating: fonts/gadugi.ttf
#   inflating: fonts/gadugib.ttf
#   inflating: fonts/GARA.TTF
#   inflating: fonts/GARABD.TTF
#   inflating: fonts/GARAIT.TTF
#   inflating: fonts/georgia.ttf
#   inflating: fonts/georgiab.ttf
#   inflating: fonts/georgiai.ttf
#   inflating: fonts/georgiaz.ttf
#   inflating: fonts/GIGI.TTF
#   inflating: fonts/GILBI___.TTF
#   inflating: fonts/GILB____.TTF
#   inflating: fonts/GILC____.TTF
#   inflating: fonts/GILI____.TTF
#   inflating: fonts/GILLUBCD.TTF
#   inflating: fonts/GILSANUB.TTF
#   inflating: fonts/GIL_____.TTF
#   inflating: fonts/GLECB.TTF
#   inflating: fonts/GLSNECB.TTF
#   inflating: fonts/GOTHIC.TTF
#   inflating: fonts/GOTHICB.TTF
#   inflating: fonts/GOTHICBI.TTF
#   inflating: fonts/GOTHICI.TTF
#   inflating: fonts/GOUDOS.TTF
#   inflating: fonts/GOUDOSB.TTF
#   inflating: fonts/GOUDOSI.TTF
#   inflating: fonts/GOUDYSTO.TTF
#   inflating: fonts/HARLOWSI.TTF
#   inflating: fonts/HARNGTON.TTF
#   inflating: fonts/HATTEN.TTF
#   inflating: fonts/himalaya.ttf
#   inflating: fonts/HTOWERT.TTF
#   inflating: fonts/HTOWERTI.TTF
#   inflating: fonts/impact.ttf
#   inflating: fonts/IMPRISHA.TTF
#   inflating: fonts/INFROMAN.TTF
#   inflating: fonts/Inkfree.ttf
#   inflating: fonts/ITCBLKAD.TTF
#   inflating: fonts/ITCEDSCR.TTF
#   inflating: fonts/ITCKRIST.TTF
#   inflating: fonts/javatext.ttf
#   inflating: fonts/JOKERMAN.TTF
#   inflating: fonts/JUICE___.TTF
#   inflating: fonts/kaiu.ttf
#   inflating: fonts/KUNSTLER.TTF
#   inflating: fonts/LATINWD.TTF
#   inflating: fonts/LBRITE.TTF
#   inflating: fonts/LBRITED.TTF
#   inflating: fonts/LBRITEDI.TTF
#   inflating: fonts/LBRITEI.TTF
#   inflating: fonts/LCALLIG.TTF
#   inflating: fonts/LeelaUIb.ttf
#   inflating: fonts/LeelawUI.ttf
#   inflating: fonts/LeelUIsl.ttf
#   inflating: fonts/LFAX.TTF
#   inflating: fonts/LFAXD.TTF
#   inflating: fonts/LFAXDI.TTF
#   inflating: fonts/LFAXI.TTF
#   inflating: fonts/LHANDW.TTF
#   inflating: fonts/LSANS.TTF
#   inflating: fonts/LSANSD.TTF
#   inflating: fonts/LSANSDI.TTF
#   inflating: fonts/LSANSI.TTF
#   inflating: fonts/LTYPE.TTF
#   inflating: fonts/LTYPEB.TTF
#   inflating: fonts/LTYPEBO.TTF
#   inflating: fonts/LTYPEO.TTF
#   inflating: fonts/lucon.ttf
#   inflating: fonts/l_10646.ttf
#   inflating: fonts/MAGNETOB.TTF
#   inflating: fonts/MAIAN.TTF
#   inflating: fonts/malgun.ttf
#   inflating: fonts/malgunbd.ttf
#   inflating: fonts/malgunsl.ttf
#   inflating: fonts/marlett.ttf
#   inflating: fonts/MATURASC.TTF
#   inflating: fonts/micross.ttf
#   inflating: fonts/MISTRAL.TTF
#   inflating: fonts/mmrtext.ttf
#   inflating: fonts/mmrtextb.ttf
#   inflating: fonts/MOD20.TTF
#   inflating: fonts/monbaiti.ttf
#   inflating: fonts/msyi.ttf
#   inflating: fonts/MTCORSVA.TTF
#   inflating: fonts/MTEXTRA.TTF
#   inflating: fonts/mvboli.ttf
#   inflating: fonts/NIAGENG.TTF
#   inflating: fonts/NIAGSOL.TTF
#   inflating: fonts/NotoSansHK-VF.ttf
#   inflating: fonts/NotoSansSC-VF.ttf
#   inflating: fonts/NotoSansTC-VF.ttf
#   inflating: fonts/NotoSerifHK-VF.ttf
#   inflating: fonts/NotoSerifSC-VF.ttf
#   inflating: fonts/NotoSerifTC-VF.ttf
#   inflating: fonts/ntailu.ttf
#   inflating: fonts/ntailub.ttf
#   inflating: fonts/OCRAEXT.TTF
#   inflating: fonts/OLDENGL.TTF
#   inflating: fonts/ONYX.TTF
#   inflating: fonts/OUTLOOK.TTF
#   inflating: fonts/pala.ttf
#   inflating: fonts/palab.ttf
#   inflating: fonts/palabi.ttf
#   inflating: fonts/palai.ttf
#   inflating: fonts/PALSCRI.TTF
#   inflating: fonts/PAPYRUS.TTF
#   inflating: fonts/PARCHM.TTF
#   inflating: fonts/PERBI___.TTF
#   inflating: fonts/PERB____.TTF
#   inflating: fonts/PERI____.TTF
#   inflating: fonts/PERTIBD.TTF
#   inflating: fonts/PERTILI.TTF
#   inflating: fonts/PER_____.TTF
#   inflating: fonts/phagspa.ttf
#   inflating: fonts/phagspab.ttf
#   inflating: fonts/PLAYBILL.TTF
#   inflating: fonts/POORICH.TTF
#   inflating: fonts/PRISTINA.TTF
#   inflating: fonts/RAGE.TTF
#   inflating: fonts/RAVIE.TTF
#   inflating: fonts/REFSAN.TTF
#   inflating: fonts/REFSPCL.TTF
#   inflating: fonts/ROCCB___.TTF
#   inflating: fonts/ROCC____.TTF
#   inflating: fonts/ROCK.TTF
#   inflating: fonts/ROCKB.TTF
#   inflating: fonts/ROCKBI.TTF
#   inflating: fonts/ROCKEB.TTF
#   inflating: fonts/ROCKI.TTF
#   inflating: fonts/SansSerifCollection.ttf
#   inflating: fonts/SCHLBKB.TTF
#   inflating: fonts/SCHLBKBI.TTF
#   inflating: fonts/SCHLBKI.TTF
#   inflating: fonts/SCRIPTBL.TTF
#   inflating: fonts/segmdl2.ttf
#   inflating: fonts/SegoeIcons.ttf
#   inflating: fonts/segoepr.ttf
#   inflating: fonts/segoeprb.ttf
#   inflating: fonts/segoesc.ttf
#   inflating: fonts/segoescb.ttf
#   inflating: fonts/segoeui.ttf
#   inflating: fonts/segoeuib.ttf
#   inflating: fonts/segoeuii.ttf
#   inflating: fonts/segoeuil.ttf
#   inflating: fonts/segoeuisl.ttf
#   inflating: fonts/segoeuiz.ttf
#   inflating: fonts/seguibl.ttf
#   inflating: fonts/seguibli.ttf
#   inflating: fonts/seguiemj.ttf
#   inflating: fonts/seguihis.ttf
#   inflating: fonts/seguili.ttf
#   inflating: fonts/seguisb.ttf
#   inflating: fonts/seguisbi.ttf
#   inflating: fonts/seguisli.ttf
#   inflating: fonts/seguisym.ttf
#   inflating: fonts/SegUIVar.ttf
#   inflating: fonts/SHOWG.TTF
#   inflating: fonts/simfang.ttf
#   inflating: fonts/simhei.ttf
#   inflating: fonts/simkai.ttf
#   inflating: fonts/SIMLI.TTF
#   inflating: fonts/simsunb.ttf
#   inflating: fonts/SimsunExtG.ttf
#   inflating: fonts/SIMYOU.TTF
#   inflating: fonts/SitkaVF-Italic.ttf
#   inflating: fonts/SitkaVF.ttf
#   inflating: fonts/SNAP____.TTF
#   inflating: fonts/STCAIYUN.TTF
#   inflating: fonts/STENCIL.TTF
#   inflating: fonts/STFANGSO.TTF
#   inflating: fonts/STHUPO.TTF
#   inflating: fonts/STKAITI.TTF
#   inflating: fonts/STLITI.TTF
#   inflating: fonts/STSONG.TTF
#   inflating: fonts/STXIHEI.TTF
#   inflating: fonts/STXINGKA.TTF
#   inflating: fonts/STXINWEI.TTF
#   inflating: fonts/STZHONGS.TTF
#   inflating: fonts/sylfaen.ttf
#   inflating: fonts/symbol.ttf
#   inflating: fonts/tahoma.ttf
#   inflating: fonts/tahomabd.ttf
#   inflating: fonts/taile.ttf
#   inflating: fonts/taileb.ttf
#   inflating: fonts/TCBI____.TTF
#   inflating: fonts/TCB_____.TTF
#   inflating: fonts/TCCB____.TTF
#   inflating: fonts/TCCEB.TTF
#   inflating: fonts/TCCM____.TTF
#   inflating: fonts/TCMI____.TTF
#   inflating: fonts/TCM_____.TTF
#   inflating: fonts/TEMPSITC.TTF
#   inflating: fonts/times.ttf
#   inflating: fonts/timesbd.ttf
#   inflating: fonts/timesbi.ttf
#   inflating: fonts/timesi.ttf
#   inflating: fonts/trebuc.ttf
#   inflating: fonts/trebucbd.ttf
#   inflating: fonts/trebucbi.ttf
#   inflating: fonts/trebucit.ttf
#   inflating: fonts/verdana.ttf
#   inflating: fonts/verdanab.ttf
#   inflating: fonts/verdanai.ttf
#   inflating: fonts/verdanaz.ttf
#   inflating: fonts/VINERITC.TTF
#   inflating: fonts/VIVALDII.TTF
#   inflating: fonts/VLADIMIR.TTF
#   inflating: fonts/webdings.ttf
#   inflating: fonts/wingding.ttf
#   inflating: fonts/WINGDNG2.TTF
#   inflating: fonts/WINGDNG3.TTF
# ✅ Generated 5000 samples in 'dataset' (labels.txt saved)
# #train=4000  #test=1000
# Device: cuda
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=VGG16_Weights.IMAGENET1K_V1`. You can also use `weights=VGG16_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
# 100%|██████████| 528M/528M [00:02<00:00, 186MB/s]
# Epoch 01 | TrainAcc=0.5497  TestAcc=0.8640
# Epoch 02 | TrainAcc=0.8375  TestAcc=0.8960
# Epoch 03 | TrainAcc=0.8700  TestAcc=0.8740
# Epoch 04 | TrainAcc=0.8748  TestAcc=0.8710
# Epoch 05 | TrainAcc=0.8625  TestAcc=0.9030
# Epoch 06 | TrainAcc=0.8875  TestAcc=0.9010
# Epoch 07 | TrainAcc=0.8902  TestAcc=0.8930
# Epoch 08 | TrainAcc=0.9010  TestAcc=0.9040
# Epoch 09 | TrainAcc=0.9077  TestAcc=0.8980
# Epoch 10 | TrainAcc=0.9025  TestAcc=0.9100
# ✅ Best test acc = 0.9100  (weights saved)
